# %%
import pandas as pd
df = pd.read_pickle('merged_data.pkl')
from datetime import datetime
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn import cross_validation, naive_bayes
import numpy as np

# %%
df.head()
# Out:
#     id_x                      email  user_id              contextio_id  \
# 0     49       gewulf1995@gmail.com        2  5467c8d8facadd226e4879f8
# 3     38    tuckerctaylor@gmail.com       34  5449c4287dfe6887055342a5
# 6     22     jonahsharris@gmail.com       14  543d3007facadd6b3c6e755a
# 7     64  marychristine42@gmail.com       65  546ec2f4064ba34e0a8dcbdc
# 11    39         kahns729@gmail.com       35  5449c54cb9f709367f389d62
#
#                            created_x schedule  \
# 0   2014-11-15 21:42:51.002044+00:00     None
# 3   2014-10-24 03:14:49.097476+00:00     None
# 6   2014-10-14 14:16:05.681155+00:00     None
# 7   2014-11-21 04:43:34.081440+00:00     None
# 11  2014-10-24 03:19:40.990557+00:00     None
#
#                               status  retries delete  \
# 0   contextio probably hasn't synced        0  False
# 3   contextio probably hasn't synced        0  False
# 6   contextio probably hasn't synced        0  False
# 7                               None        0  False
# 11  contextio probably hasn't synced        0  False
#
#                                            email_json  \
# 0                                                None
# 3                                                None
# 6                                                None
# 7   [{u'folders': [u'SeaTrek', u'\Important', u'[G...
# 11                                               None
#
#                           ...                          \
# 0                         ...
# 3                         ...
# 6                         ...
# 7                         ...
# 11                        ...
#
#                                       pos_count_month  \
# 0   {u'1228093261': {u'MD': 1, u'VB': 2, u'VBG': 2...
# 3   {u'1309482061': {u'PRP$': 6, u'VBG': 4, u'VBD'...
# 6   {u'1412125261': {u'VB': 1, u'NN': 15, u'CC': 4...
# 7   {u'1370048461': {u'PRP$': 6, u'VBG': 11, u'VBD...
# 11  {u'1409533261': {u'NN': 7, u',': 2, u'CD': 4, ...
#
#                                       pos_count_words analyze_time  \
# 0   {u'50000': {u'PRP$': 46, u'VBG': 54, u'VBD': 4...           17
# 3   {u'0': {u'PRP$': 40, u'VBG': 54, u'VBD': 61, u...            4
# 6   {u'0': {u'PRP$': 1, u'VBG': 5, u'VBD': 2, u'VB...            1
# 7   {u'150000': {u'PRP$': 20, u'VBG': 17, u'VBD': ...           42
# 11  {u'0': {u'PRP$': 13, u'VBG': 16, u'VBD': 14, u...            1
#
#    download_time                              singular_plural_month  \
# 0            158  {u'1228093261': {u'plural': 1, u'singular': 23...
# 3             45  {u'1309482061': {u'plural': 14, u'singular': 2...
# 6             10  {u'1412125261': {u'plural': 0, u'singular': 23...
# 7           2384  {u'1370048461': {u'plural': 26, u'singular': 5...
# 11            15  {u'1409533261': {u'plural': 0, u'singular': 29...
#
#                                 singular_plural_words  \
# 0   {u'0': {u'plural': 442, u'singular': 9574}, u'...
# 3         {u'0': {u'plural': 361, u'singular': 7875}}
# 6           {u'0': {u'plural': 21, u'singular': 400}}
# 7   {u'50000': {u'plural': 452, u'singular': 9624}...
# 11          {u'0': {u'plural': 32, u'singular': 627}}
#
#                            average_email_length_words  \
# 0              {u'0': 38, u'10000': 68, u'20000': 34}
# 3                                          {u'0': 64}
# 6                                          {u'0': 28}
# 7   {u'50000': 58, u'10000': 75, u'30000': 97, u'0...
# 11                                         {u'0': 54}
#
#                           average_response_time_month  \
# 0   {u'1264986061': {u'total_time': 174792, u'min_...
# 3   {u'1309482061': {u'total_time': 54746, u'min_t...
# 6   {u'1333242061': {u'total_time': 327, u'min_tim...
# 7   {u'1370048461': {u'total_time': 3466574, u'min...
# 11  {u'1398906061': {u'total_time': 2756, u'min_ti...
#
#                                          bag_of_words  \
# 0   {u'1228093261': {u'just': 1, u'am': 1, u'see':...
# 3   {u'1309482061': {u'all': 1, u'least': 1, u'jus...
# 6   {u'1412125261': {u'c': 2, u'b': 2, u'pd': 1, u...
# 7   {u'1370048461': {u'summer': 4, u'all': 4, u'he...
# 11  {u'1409533261': {u'sep': 1, u'leaman': 1, u'te...
#
#                                    bag_of_words_total
# 0   {u'saver': 1, u'foul': 1, u'four': 1, u'164': ...
# 3   {u'all': 21, u'examin': 1, u'rob': 3, u'celebr...
# 6   {u'explan': 1, u'mind': 1, u'kkk': 1, u'just':...
# 7   {u'bigey': 2, u'yellow': 1, u'four': 12, u'jea...
# 11  {u'all': 1, u'code': 1, u'help': 1, u'just': 2...
#
# [5 rows x 33 columns]

# %% [markdown]
# ##ngram repetion t-test

# %%
winter = [12,1,2]
summer = [6,7,8]
hot = []
cold = []
for person in df.ngram_frequency_month.iteritems():
    for key, value in person[1].iteritems():
        month = datetime.fromtimestamp(float(key)).date().month
        if month in winter:
            cold.append(value[0])
        elif month in summer:
            hot.append(value[0])

# %%
paired_sample = ttest_ind(hot, cold)

print "The t-statistic is %.3f and the p-value is %.3f." % paired_sample
# Out:
# The t-statistic is 0.509 and the p-value is 0.611.

# %% [markdown]
# ##bag of words naive bayes (comparing seasons)

# %%
cold = []
hot = []
winter = [12,1,2]
summer = [6,7,8]
for month_bags in df.bag_of_words:
    for bag in month_bags.iteritems():
        month = datetime.fromtimestamp(float(bag[0])).date().month
        if month in winter:
            cold.append({'summer': False, 'bag': bag[1]})
        elif month in summer:
            hot.append({'summer': True, 'bag': bag[1]})
seasons = pd.DataFrame.from_records(hot + cold)

# %%
seasons.tail()
# Out:
#                                                   bag summer
# 26  {u'all': 1, u'help': 6, u'show': 1, u'over': 2...  False
# 27  {u'shop': 1, u'just': 1, u'yshoppingarticl': 1...  False
# 28  {u'and': 1, u'is': 1, u'realli': 1, u'radio': ...  False
# 29  {u'1st': 1, u'comment': 1, u'all': 1, u'help':...  False
# 30  {u'coach': 1, u'navianc': 1, u'consider': 1, u...  False

# %%
v = DictVectorizer()
X = v.fit_transform(seasons.bag)
X = X.tocsc()
Y = seasons.summer.values.astype(np.int)
X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(X,Y)
clf = naive_bayes.MultinomialNB(fit_prior=False, alpha=0.5)
clf.fit(X_train, Y_train)
print "Accuracy: %0.2f%%" % (100 * clf.score(X_test, Y_test))
# Out:
# Accuracy: 71.65%

# %%
words = np.array(v.get_feature_names())

x = np.eye(X_test.shape[1])
probs = clf.predict_log_proba(x)[:, 0]
ind = np.argsort(probs)

summer_words = words[ind[:10]]
winter_words = words[ind[-10:]]

summer_prob = probs[ind[:10]]
winter_prob = probs[ind[-10:]]

print "Summer words\t P(summer | word)"
for w, p in zip(summer_words, summer_prob):
    print "%20s" % w, "%0.2f" % (1 - np.exp(p))
    
print "\nWinter words\t P(winter | word)"
for w, p in zip(winter_words, winter_prob):
    print "%20s" % w, "%0.2f" % (1 - np.exp(p))
# Out:
# Summer words	 P(summer | word)
#                  ift 1.00
#                   tt 1.00
#                   ​​ 1.00
#                  aug 0.99
#             pricelin 0.99
#                 nerd 0.99
#                  jul 0.99
#                  e1t 0.99
#               hsms03 0.99
#        virginamerica 0.99
#
# Winter words	 P(winter | word)
#                 voki 0.01
#                 a248 0.00
#                 5879 0.00
#                  248 0.00
#               akamai 0.00
#             travelpn 0.00
#                  feb 0.00
#             optonlin 0.00
#                  			0.00
#                  rbc 0.00

# %% [markdown]
# ##gender munging

# %%
male = []
female = []
with open('genders.txt', 'r') as f:
    for line in f:
        if(line.split()[1] == 'm'):
            male.append(line.split()[0])
        elif(line.split()[1] == 'f'):
            female.append(line.split()[0])

# %%
for indx, row in df.iterrows():
    if(row['gender'] is None):
        if(row['email'] in male):
            row['gender'] = 'm'
        else:
            row['gender'] = 'f'
